# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1227cb0b8>,
#   <matplotlib.axis.XTick at 0x1227a49e8>,
#   <matplotlib.axis.XTick at 0x1227ecd30>,
#   <matplotlib.axis.XTick at 0x122ac6ac8>,
#   <matplotlib.axis.XTick at 0x122ac6e48>,
#   <matplotlib.axis.XTick at 0x122ad3400>,
#   <matplotlib.axis.XTick at 0x122ad3978>,
#   <matplotlib.axis.XTick at 0x122ad3ef0>,
#   <matplotlib.axis.XTick at 0x122adc4a8>,
#   <matplotlib.axis.XTick at 0x122adca20>,
#   <matplotlib.axis.XTick at 0x122adce80>,
#   <matplotlib.axis.XTick at 0x122ae2550>,
#   <matplotlib.axis.XTick at 0x122ae2ac8>,
#   <matplotlib.axis.XTick at 0x122ae2630>,
#   <matplotlib.axis.XTick at 0x122adc828>,
#   <matplotlib.axis.XTick at 0x122ad3278>,
#   <matplotlib.axis.XTick at 0x122ae8588>,
#   <matplotlib.axis.XTick at 0x122ae8b00>,
#   <matplotlib.axis.XTick at 0x122af0128>,
#   <matplotlib.axis.XTick at 0x122af0630>,
#   <matplotlib.axis.XTick at 0x122af0ba8>,
#   <matplotlib.axis.XTick at 0x122af7198>,
#   <matplotlib.axis.XTick at 0x122af76d8>,
#   <matplotlib.axis.XTick at 0x122af0f98>,
#   <matplotlib.axis.XTick at 0x122ac6898>,
#   <matplotlib.axis.XTick at 0x122af7208>,
#   <matplotlib.axis.XTick at 0x122afe160>,
#   <matplotlib.axis.XTick at 0x122afe6a0>,
#   <matplotlib.axis.XTick at 0x122afec18>,
#   <matplotlib.axis.XTick at 0x122b031d0>,
#   <matplotlib.axis.XTick at 0x122b03748>,
#   <matplotlib.axis.XTick at 0x122b03cc0>,
#   <matplotlib.axis.XTick at 0x122b0c278>,
#   <matplotlib.axis.XTick at 0x122b03828>,
#   <matplotlib.axis.XTick at 0x122ad38d0>,
#   <matplotlib.axis.XTick at 0x122b0c6a0>,
#   <matplotlib.axis.XTick at 0x122b0cc18>,
#   <matplotlib.axis.XTick at 0x122b121d0>,
#   <matplotlib.axis.XTick at 0x122b12748>,
#   <matplotlib.axis.XTick at 0x122b12cc0>,
#   <matplotlib.axis.XTick at 0x122b1a278>,
#   <matplotlib.axis.XTick at 0x122b1a7f0>,
#   <matplotlib.axis.XTick at 0x122b1ad68>,
#   <matplotlib.axis.XTick at 0x122b12c18>,
#   <matplotlib.axis.XTick at 0x122b0cb70>,
#   <matplotlib.axis.XTick at 0x122ae2e48>,
#   <matplotlib.axis.XTick at 0x122b20518>,
#   <matplotlib.axis.XTick at 0x122b20a90>,
#   <matplotlib.axis.XTick at 0x122b280b8>,
#   <matplotlib.axis.XTick at 0x122b285c0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("avg_state_rain.png")
plt.show()
